# %% [markdown]
# # Capstone Project

# %% [markdown]
# ### Flatiron School

# %% [markdown]
# ### By Acusio Bivona

# %%
#Team IDs
#Dodgers 119
#Yankees 147

# %%
import requests
import time

time.sleep(5)

url = "https://mlb-data.p.rapidapi.com/json/named.roster_40.bam"

querystring = {"team_id":"'119'"}

headers = {
    'x-rapidapi-host': "mlb-data.p.rapidapi.com",
    'x-rapidapi-key': "96bb6e2228msh55393630fa64dbbp12e689jsn961aa3a10166"
    }

response_LAD = requests.request("GET", url, headers=headers, params=querystring)

print(response_LAD.text)
# Out:
# {"roster_40":{"copyRight":" Copyright 2020 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt  ","queryResults":{"created":"2020-07-09T18:01:12","totalSize":"42","row":[{"position_txt":"P","weight":"195","name_display_first_last":"Scott Alexander","college":"Sonoma State, CA","height_inches":"2","starter_sw":"N","jersey_number":"75","end_date":"","name_first":"Scott","bats":"L","team_code":"lan","height_feet":"6","pro_debut_date":"2015-09-02T00:00:00","status_code":"A","primary_position":"1","birth_date":"1989-07-10T00:00:00","team_abbrev":"LAD","throws":"L","team_name":"Los Angeles Dodgers","name_display_last_first":"Alexander, Scott","name_use":"Scott","player_id":"518397","name_last":"Alexander","team_id":"119","start_date":"2018-01-04T00:00:00","name_full":"Alexander, Scott"},{"position_txt":"P","weight":"232","name_display_first_last":"Pedro Baez","college":"","height_inches":"0","starter_sw":"N","jersey_number":"52","end_date":"","name_first":"Pedro","bats":"R","team_code":"lan","height_feet":"6","pro_debut_date":"2014-05-05T00:00:00","status_code":"D10","primary_position":"1","birth_date":"1988-03-11T00:00:00","team_abbrev":"LAD","throws":"R","team_name":"Los Angeles Dodgers","name_display_last_first":"Baez, Pedro","name_use":"Pedro","player_id":"520980","name_last":"Baez","team_id":"119","start_date":"2013-11-20T00:00:00","name_full":"Baez, Pedro"},{"position_txt":"C","weight":"187","name_display_first_last":"Austin Barnes","college":"Arizona State","height_inches":"10","starter_sw":"N","jersey_number":"15","end_date":"","name_first":"Austin","bats":"R","team_code":"lan","height_feet":"5","pro_debut_date":"2015-05-24T00:00:00","status_code":"A","primary_position":"2","birth_date":"1989-12-28T00:00:00","team_abbrev":"LAD","throws":"R","team_name":"Los Angeles Dodgers","name_display_last_first":"Barnes, Austin","name_use":"Austin","player_id":"605131","name_last":"Barnes","team_id":"119","start_date":"2014-12-11T00:00:00","name_full":"Barnes, Austin"},{"position_txt":"1B","weight":"215","name_display_first_last":"Matt Beaty","college":"Belmont","height_inches":"0","starter_sw":"N","jersey_number":"45","end_date":"","name_first":"Matthew","bats":"L","team_code":"lan","height_feet":"6","pro_debut_date":"2019-04-30T00:00:00","status_code":"A","primary_position":"3","birth_date":"1993-04-28T00:00:00","team_abbrev":"LAD","throws":"R","team_name":"Los Angeles Dodgers","name_display_last_first":"Beaty, Matt","name_use":"Matt","player_id":"607461","name_last":"Beaty","team_id":"119","start_date":"2018-11-20T00:00:00","name_full":"Beaty, Matt"},{"position_txt":"RF","weight":"203","name_display_first_last":"Cody Bellinger","college":"","height_inches":"4","starter_sw":"N","jersey_number":"35","end_date":"","name_first":"Cody","bats":"L","team_code":"lan","height_feet":"6","pro_debut_date":"2017-04-25T00:00:00","status_code":"A","primary_position":"9","birth_date":"1995-07-13T00:00:00","team_abbrev":"LAD","throws":"L","team_name":"Los Angeles Dodgers","name_display_last_first":"Bellinger, Cody","name_use":"Cody","player_id":"641355","name_last":"Bellinger","team_id":"119","start_date":"2017-04-25T00:00:00","name_full":"Bellinger, Cody"},{"position_txt":"RF","weight":"180","name_display_first_last":"Mookie Betts","college":"","height_inches":"9","starter_sw":"N","jersey_number":"50","end_date":"","name_first":"Markus","bats":"R","team_code":"lan","height_feet":"5","pro_debut_date":"2014-06-29T00:00:00","status_code":"A","primary_position":"9","birth_date":"1992-10-07T00:00:00","team_abbrev":"LAD","throws":"R","team_name":"Los Angeles Dodgers","name_display_last_first":"Betts, Mookie","name_use":"Mookie","player_id":"605141","name_last":"Betts","team_id":"119","start_date":"2020-02-10T00:00:00","name_full":"Betts, Mookie"},{"position_txt":"P","weight":"185","name_display_first_last":"Walker Buehler","college":"Vanderbilt","height_inches ...

# %%
response_LAD.json().keys()
# Out:
# dict_keys(['roster_40'])

# %%
for key in response_LAD.json().keys():
    print(key)
    value = response_LAD.json()[key]
    print(type(value))
    print('\n\n')
# Out:
# roster_40
# <class 'dict'>

# %%
response_LAD.json()['roster_40']
# Out:
# {'copyRight': ' Copyright 2020 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt  ',
#  'queryResults': {'created': '2020-07-09T18:01:12',
#   'totalSize': '42',
#   'row': [{'position_txt': 'P',
#     'weight': '195',
#     'name_display_first_last': 'Scott Alexander',
#     'college': 'Sonoma State, CA',
#     'height_inches': '2',
#     'starter_sw': 'N',
#     'jersey_number': '75',
#     'end_date': '',
#     'name_first': 'Scott',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2015-09-02T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1989-07-10T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'L',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Alexander, Scott',
#     'name_use': 'Scott',
#     'player_id': '518397',
#     'name_last': 'Alexander',
#     'team_id': '119',
#     'start_date': '2018-01-04T00:00:00',
#     'name_full': 'Alexander, Scott'},
#    {'position_txt': 'P',
#     'weight': '232',
#     'name_display_first_last': 'Pedro Baez',
#     'college': '',
#     'height_inches': '0',
#     'starter_sw': 'N',
#     'jersey_number': '52',
#     'end_date': '',
#     'name_first': 'Pedro',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2014-05-05T00:00:00',
#     'status_code': 'D10',
#     'primary_position': '1',
#     'birth_date': '1988-03-11T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Baez, Pedro',
#     'name_use': 'Pedro',
#     'player_id': '520980',
#     'name_last': 'Baez',
#     'team_id': '119',
#     'start_date': '2013-11-20T00:00:00',
#     'name_full': 'Baez, Pedro'},
#    {'position_txt': 'C',
#     'weight': '187',
#     'name_display_first_last': 'Austin Barnes',
#     'college': 'Arizona State',
#     'height_inches': '10',
#     'starter_sw': 'N',
#     'jersey_number': '15',
#     'end_date': '',
#     'name_first': 'Austin',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '5',
#     'pro_debut_date': '2015-05-24T00:00:00',
#     'status_code': 'A',
#     'primary_position': '2',
#     'birth_date': '1989-12-28T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Barnes, Austin',
#     'name_use': 'Austin',
#     'player_id': '605131',
#     'name_last': 'Barnes',
#     'team_id': '119',
#     'start_date': '2014-12-11T00:00:00',
#     'name_full': 'Barnes, Austin'},
#    {'position_txt': '1B',
#     'weight': '215',
#     'name_display_first_last': 'Matt Beaty',
#     'college': 'Belmont',
#     'height_inches': '0',
#     'starter_sw': 'N',
#     'jersey_number': '45',
#     'end_date': '',
#     'name_first': 'Matthew',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2019-04-30T00:00:00',
#     'status_code': 'A',
#     'primary_position': '3',
#     'birth_date': '1993-04-28T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Beaty, Matt',
#     'name_use': 'Matt',
#     'player_id': '607461',
#     'name_last': 'Beaty',
#     'team_id': '119',
#     'start_date': '2018-11-20T00:00:00',
#     'name_full': 'Beaty, Matt'},
#    {'position_txt': 'RF',
#     'weight': '203',
#     'name_display_first_last': 'Cody Bellinger',
#     'college': '',
#     'height_inches': '4',
#     'starter_sw': 'N',
#     'jersey_number': '35',
#     'end_date': '',
#     'name_first': 'Cody',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2017-04-25T00:00:00',
#     'status_code': 'A',
#     'primary_position': '9',
#     'birth_date': '1995-07-13T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'L',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Bellinger, Cody',
#     'name_use': 'Cody',
#     'player_id': '641355',
#     'name_last': 'Bellinger',
#     'team_id': '119',
#     'start_date': '2017-04-25T00:00:00',
#     'name_full': 'Bellinger, Cody'},
#    {'position_txt': 'RF',
#     'weight': '180',
#     'name_display_first_last': 'Mookie Betts',
#     'college': '',
#     'height_inches': '9',
#     'starter_sw': 'N',
#     'jersey_number': '50',
#     'end_date': '',
#     'name_first': 'Markus',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '5',
#     'pro_debut_date': '2014-06-29T00:00:00',
#     'status_code': 'A',
#     'primary_position': '9',
#     'birth_date': '1992-10-07T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Betts, Mookie',
#     'name_use': 'Mookie',
#     'player_id': '605141',
#     'name_last': 'Betts',
#     'team_id': '119',
#     'start_date': '2020-02-10T00:00:00',
#     'name_full': 'Betts, Mookie'},
#    {'position_txt': 'P',
#     'weight': '185',
#     'name_display_first_last': 'Walker Buehler',
#     'college': 'Vanderbilt',
#     'height_inches': '2',
#     'starter_sw': 'N',
#     'jersey_number': '21',
#     'end_date': '',
#     'name_first': 'Walker',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2017-09-07T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1994-07-28T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Buehler, Walker',
#     'name_use': 'Walker',
#     'player_id': '621111',
#     'name_last': 'Buehler',
#     'team_id': '119',
#     'start_date': '2017-09-06T00:00:00',
#     'name_full': 'Buehler, Walker'},
#    {'position_txt': 'P',
#     'weight': '226',
#     'name_display_first_last': 'Caleb Ferguson',
#     'college': '',
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '64',
#     'end_date': '',
#     'name_first': 'Caleb',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2018-06-06T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1996-07-02T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'L',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Ferguson, Caleb',
#     'name_use': 'Caleb',
#     'player_id': '657571',
#     'name_last': 'Ferguson',
#     'team_id': '119',
#     'start_date': '2018-06-06T00:00:00',
#     'name_full': 'Ferguson, Caleb'},
#    {'position_txt': 'P',
#     'weight': '203',
#     'name_display_first_last': 'Dylan Floro',
#     'college': 'Cal State Fullerton',
#     'height_inches': '2',
#     'starter_sw': 'N',
#     'jersey_number': '51',
#     'end_date': '',
#     'name_first': 'Dylan',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2016-07-07T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1990-12-27T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Floro, Dylan',
#     'name_use': 'Dylan',
#     'player_id': '571670',
#     'name_last': 'Floro',
#     'team_id': '119',
#     'start_date': '2018-07-04T00:00:00',
#     'name_full': 'Floro, Dylan'},
#    {'position_txt': 'P',
#     'weight': '205',
#     'name_display_first_last': 'Tony Gonsolin',
#     'college': "St. Mary's",
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '46',
#     'end_date': '',
#     'name_first': 'Anthony',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2019-06-26T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1994-05-14T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Gonsolin, Tony',
#     'name_use': 'Tony',
#     'player_id': '664062',
#     'name_last': 'Gonsolin',
#     'team_id': '119',
#     'start_date': '2019-06-26T00:00:00',
#     'name_full': 'Gonsolin, Tony'},
#    {'position_txt': 'P',
#     'weight': '180',
#     'name_display_first_last': 'Victor Gonzalez',
#     'college': '',
#     'height_inches': '0',
#     'starter_sw': 'N',
#     'jersey_number': '81',
#     'end_date': '',
#     'name_first': 'Victor',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '1',
#     'birth_date': '1995-11-16T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'L',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Gonzalez, Victor',
#     'name_use': 'Victor',
#     'player_id': '624647',
#     'name_last': 'Gonzalez',
#     'team_id': '119',
#     'start_date': '2019-10-31T00:00:00',
#     'name_full': 'Gonzalez, Victor'},
#    {'position_txt': 'P',
#     'weight': '265',
#     'name_display_first_last': 'Brusdar Graterol',
#     'college': '',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '48',
#     'end_date': '',
#     'name_first': 'Brusdar',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2019-09-01T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1998-08-26T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Graterol, Brusdar',
#     'name_use': 'Brusdar',
#     'player_id': '660813',
#     'name_last': 'Graterol',
#     'team_id': '119',
#     'start_date': '2020-02-10T00:00:00',
#     'name_full': 'Graterol, Brusdar'},
#    {'position_txt': '2B',
#     'weight': '190',
#     'name_display_first_last': 'Enrique Hernandez',
#     'college': '',
#     'height_inches': '11',
#     'starter_sw': 'N',
#     'jersey_number': '14',
#     'end_date': '',
#     'name_first': 'Enrique',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '5',
#     'pro_debut_date': '2014-07-01T00:00:00',
#     'status_code': 'A',
#     'primary_position': '4',
#     'birth_date': '1991-08-24T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Hernandez, Enrique',
#     'name_use': 'Enrique',
#     'player_id': '571771',
#     'name_last': 'Hernandez',
#     'team_id': '119',
#     'start_date': '2014-12-11T00:00:00',
#     'name_full': 'Hernandez, Enrique'},
#    {'position_txt': 'P',
#     'weight': '265',
#     'name_display_first_last': 'Kenley Jansen',
#     'college': '',
#     'height_inches': '5',
#     'starter_sw': 'N',
#     'jersey_number': '74',
#     'end_date': '',
#     'name_first': 'Kenley',
#     'bats': 'S',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2010-07-24T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1987-09-30T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Jansen, Kenley',
#     'name_use': 'Kenley',
#     'player_id': '445276',
#     'name_last': 'Jansen',
#     'team_id': '119',
#     'start_date': '2018-08-20T00:00:00',
#     'name_full': 'Jansen, Kenley'},
#    {'position_txt': 'P',
#     'weight': '174',
#     'name_display_first_last': 'Joe Kelly',
#     'college': 'UC Riverside',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '17',
#     'end_date': '',
#     'name_first': 'Joseph',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2012-06-10T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1988-06-09T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Kelly, Joe',
#     'name_use': 'Joe',
#     'player_id': '523260',
#     'name_last': 'Kelly',
#     'team_id': '119',
#     'start_date': '2018-12-21T00:00:00',
#     'name_full': 'Kelly, Joe'},
#    {'position_txt': 'P',
#     'weight': '225',
#     'name_display_first_last': 'Clayton Kershaw',
#     'college': '',
#     'height_inches': '4',
#     'starter_sw': 'Y',
#     'jersey_number': '22',
#     'end_date': '',
#     'name_first': 'Clayton',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2008-05-25T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1988-03-19T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'L',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Kershaw, Clayton',
#     'name_use': 'Clayton',
#     'player_id': '477132',
#     'name_last': 'Kershaw',
#     'team_id': '119',
#     'start_date': '2008-09-02T00:00:00',
#     'name_full': 'Kershaw, Clayton'},
#    {'position_txt': 'P',
#     'weight': '215',
#     'name_display_first_last': 'Adam Kolarek',
#     'college': 'Maryland',
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '56',
#     'end_date': '',
#     'name_first': 'Adam',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2017-06-29T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1989-01-14T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'L',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Kolarek, Adam',
#     'name_use': 'Adam',
#     'player_id': '592473',
#     'name_last': 'Kolarek',
#     'team_id': '119',
#     'start_date': '2019-07-31T00:00:00',
#     'name_full': 'Kolarek, Adam'},
#    {'position_txt': '2B',
#     'weight': '190',
#     'name_display_first_last': 'Gavin Lux',
#     'college': '',
#     'height_inches': '2',
#     'starter_sw': 'N',
#     'jersey_number': '9',
#     'end_date': '',
#     'name_first': 'Gavin',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2019-09-02T00:00:00',
#     'status_code': 'A',
#     'primary_position': '4',
#     'birth_date': '1997-11-23T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Lux, Gavin',
#     'name_use': 'Gavin',
#     'player_id': '666158',
#     'name_last': 'Lux',
#     'team_id': '119',
#     'start_date': '2019-09-02T00:00:00',
#     'name_full': 'Lux, Gavin'},
#    {'position_txt': 'P',
#     'weight': '180',
#     'name_display_first_last': 'Dustin May',
#     'college': '',
#     'height_inches': '6',
#     'starter_sw': 'N',
#     'jersey_number': '85',
#     'end_date': '',
#     'name_first': 'Dustin',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2019-08-02T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1997-09-06T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'May, Dustin',
#     'name_use': 'Dustin',
#     'player_id': '669160',
#     'name_last': 'May',
#     'team_id': '119',
#     'start_date': '2019-08-02T00:00:00',
#     'name_full': 'May, Dustin'},
#    {'position_txt': '2B',
#     'weight': '180',
#     'name_display_first_last': 'Zach McKinstry',
#     'college': 'Central Michigan',
#     'height_inches': '0',
#     'starter_sw': 'N',
#     'jersey_number': '73',
#     'end_date': '',
#     'name_first': 'Zachary',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '4',
#     'birth_date': '1995-04-29T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'McKinstry, Zach',
#     'name_use': 'Zach',
#     'player_id': '656716',
#     'name_last': 'McKinstry',
#     'team_id': '119',
#     'start_date': '2019-11-20T00:00:00',
#     'name_full': 'McKinstry, Zach'},
#    {'position_txt': '1B',
#     'weight': '215',
#     'name_display_first_last': 'Max Muncy',
#     'college': 'Baylor',
#     'height_inches': '0',
#     'starter_sw': 'N',
#     'jersey_number': '13',
#     'end_date': '',
#     'name_first': 'Maxwell',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2015-04-25T00:00:00',
#     'status_code': 'A',
#     'primary_position': '3',
#     'birth_date': '1990-08-25T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Muncy, Max',
#     'name_use': 'Max',
#     'player_id': '571970',
#     'name_last': 'Muncy',
#     'team_id': '119',
#     'start_date': '2018-04-17T00:00:00',
#     'name_full': 'Muncy, Max'},
#    {'position_txt': 'P',
#     'weight': '250',
#     'name_display_first_last': 'Jimmy Nelson',
#     'college': 'Alabama',
#     'height_inches': '6',
#     'starter_sw': 'N',
#     'jersey_number': '40',
#     'end_date': '',
#     'name_first': 'James',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2013-09-06T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1989-06-05T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Nelson, Jimmy',
#     'name_use': 'Jimmy',
#     'player_id': '519076',
#     'name_last': 'Nelson',
#     'team_id': '119',
#     'start_date': '2020-01-08T00:00:00',
#     'name_full': 'Nelson, Jimmy'},
#    {'position_txt': 'LF',
#     'weight': '220',
#     'name_display_first_last': 'Joc Pederson',
#     'college': '',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '31',
#     'end_date': '',
#     'name_first': 'Joc',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2014-09-01T00:00:00',
#     'status_code': 'A',
#     'primary_position': '7',
#     'birth_date': '1992-04-21T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'L',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Pederson, Joc',
#     'name_use': 'Joc',
#     'player_id': '592626',
#     'name_last': 'Pederson',
#     'team_id': '119',
#     'start_date': '2014-09-01T00:00:00',
#     'name_full': 'Pederson, Joc'},
#    {'position_txt': 'CF',
#     'weight': '225',
#     'name_display_first_last': 'DJ Peters',
#     'college': 'Western Nevada CC',
#     'height_inches': '6',
#     'starter_sw': 'N',
#     'jersey_number': '70',
#     'end_date': '',
#     'name_first': 'DJ',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '8',
#     'birth_date': '1995-12-12T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Peters, DJ',
#     'name_use': 'DJ',
#     'player_id': '656847',
#     'name_last': 'Peters',
#     'team_id': '119',
#     'start_date': '2019-11-20T00:00:00',
#     'name_full': 'Peters, DJ'},
#    {'position_txt': 'CF',
#     'weight': '210',
#     'name_display_first_last': 'A.J. Pollock',
#     'college': 'Notre Dame',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '11',
#     'end_date': '',
#     'name_first': 'Allen',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2012-04-18T00:00:00',
#     'status_code': 'A',
#     'primary_position': '8',
#     'birth_date': '1987-12-05T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Pollock, A.J.',
#     'name_use': 'A.J.',
#     'player_id': '572041',
#     'name_last': 'Pollock',
#     'team_id': '119',
#     'start_date': '2019-01-26T00:00:00',
#     'name_full': 'Pollock, A.J.'},
#    {'position_txt': 'RF',
#     'weight': '235',
#     'name_display_first_last': 'Luke Raley',
#     'college': 'Lake Erie College',
#     'height_inches': '4',
#     'starter_sw': 'N',
#     'jersey_number': '62',
#     'end_date': '',
#     'name_first': 'Lucas',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '9',
#     'birth_date': '1994-09-19T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Raley, Luke',
#     'name_use': 'Luke',
#     'player_id': '670042',
#     'name_last': 'Raley',
#     'team_id': '119',
#     'start_date': '2020-02-10T00:00:00',
#     'name_full': 'Raley, Luke'},
#    {'position_txt': 'LF',
#     'weight': '190',
#     'name_display_first_last': 'Zach Reks',
#     'college': 'Kentucky',
#     'height_inches': '2',
#     'starter_sw': 'N',
#     'jersey_number': '88',
#     'end_date': '',
#     'name_first': 'Zach',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'D10',
#     'primary_position': '7',
#     'birth_date': '1993-11-12T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Reks, Zach',
#     'name_use': 'Zach',
#     'player_id': '676646',
#     'name_last': 'Reks',
#     'team_id': '119',
#     'start_date': '2020-01-24T00:00:00',
#     'name_full': 'Reks, Zach'},
#    {'position_txt': '3B',
#     'weight': '220',
#     'name_display_first_last': 'Edwin Rios',
#     'college': 'Florida International',
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '43',
#     'end_date': '',
#     'name_first': 'Edwin',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2019-06-27T00:00:00',
#     'status_code': 'A',
#     'primary_position': '5',
#     'birth_date': '1994-04-21T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Rios, Edwin',
#     'name_use': 'Edwin',
#     'player_id': '621458',
#     'name_last': 'Rios',
#     'team_id': '119',
#     'start_date': '2018-11-20T00:00:00',
#     'name_full': 'Rios, Edwin'},
#    {'position_txt': 'C',
#     'weight': '225',
#     'name_display_first_last': 'Keibert Ruiz',
#     'college': '',
#     'height_inches': '0',
#     'starter_sw': 'N',
#     'jersey_number': '67',
#     'end_date': '',
#     'name_first': 'Keibert',
#     'bats': 'S',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '2',
#     'birth_date': '1998-07-20T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Ruiz, Keibert',
#     'name_use': 'Keibert',
#     'player_id': '660688',
#     'name_last': 'Ruiz',
#     'team_id': '119',
#     'start_date': '2018-11-20T00:00:00',
#     'name_full': 'Ruiz, Keibert'},
#    {'position_txt': 'P',
#     'weight': '190',
#     'name_display_first_last': 'Dennis Santana',
#     'college': '',
#     'height_inches': '2',
#     'starter_sw': 'N',
#     'jersey_number': '77',
#     'end_date': '',
#     'name_first': 'Dennis',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2018-06-01T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1996-04-12T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Santana, Dennis',
#     'name_use': 'Dennis',
#     'player_id': '642701',
#     'name_last': 'Santana',
#     'team_id': '119',
#     'start_date': '2017-11-20T00:00:00',
#     'name_full': 'Santana, Dennis'},
#    {'position_txt': 'P',
#     'weight': '215',
#     'name_display_first_last': 'Josh Sborz',
#     'college': 'Virginia',
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '76',
#     'end_date': '',
#     'name_first': 'Joshua',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2019-06-20T00:00:00',
#     'status_code': 'RM',
#     'primary_position': '1',
#     'birth_date': '1993-12-17T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Sborz, Josh',
#     'name_use': 'Josh',
#     'player_id': '622250',
#     'name_last': 'Sborz',
#     'team_id': '119',
#     'start_date': '2018-11-20T00:00:00',
#     'name_full': 'Sborz, Josh'},
#    {'position_txt': 'SS',
#     'weight': '215',
#     'name_display_first_last': 'Corey Seager',
#     'college': '',
#     'height_inches': '4',
#     'starter_sw': 'N',
#     'jersey_number': '5',
#     'end_date': '',
#     'name_first': 'Corey',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2015-09-03T00:00:00',
#     'status_code': 'A',
#     'primary_position': '6',
#     'birth_date': '1994-04-27T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Seager, Corey',
#     'name_use': 'Corey',
#     'player_id': '608369',
#     'name_last': 'Seager',
#     'team_id': '119',
#     'start_date': '2015-09-03T00:00:00',
#     'name_full': 'Seager, Corey'},
#    {'position_txt': 'C',
#     'weight': '195',
#     'name_display_first_last': 'Will Smith',
#     'college': 'Louisville',
#     'height_inches': '10',
#     'starter_sw': 'N',
#     'jersey_number': '16',
#     'end_date': '',
#     'name_first': 'William',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '5',
#     'pro_debut_date': '2019-05-28T00:00:00',
#     'status_code': 'A',
#     'primary_position': '2',
#     'birth_date': '1995-03-28T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Smith, Will',
#     'name_use': 'Will',
#     'player_id': '669257',
#     'name_last': 'Smith',
#     'team_id': '119',
#     'start_date': '2019-05-27T00:00:00',
#     'name_full': 'Smith, Will'},
#    {'position_txt': 'P',
#     'weight': '220',
#     'name_display_first_last': 'Ross Stripling',
#     'college': 'Texas A&M',
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '68',
#     'end_date': '',
#     'name_first': 'Thomas',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2016-04-08T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1989-11-23T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Stripling, Ross',
#     'name_use': 'Ross',
#     'player_id': '548389',
#     'name_last': 'Stripling',
#     'team_id': '119',
#     'start_date': '2015-11-20T00:00:00',
#     'name_full': 'Stripling, Ross'},
#    {'position_txt': 'LF',
#     'weight': '196',
#     'name_display_first_last': 'Chris Taylor',
#     'college': 'Virginia',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '3',
#     'end_date': '',
#     'name_first': 'Christopher',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2014-07-24T00:00:00',
#     'status_code': 'A',
#     'primary_position': '7',
#     'birth_date': '1990-08-29T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Taylor, Chris',
#     'name_use': 'Chris',
#     'player_id': '621035',
#     'name_last': 'Taylor',
#     'team_id': '119',
#     'start_date': '2016-06-19T00:00:00',
#     'name_full': 'Taylor, Chris'},
#    {'position_txt': 'RF',
#     'weight': '211',
#     'name_display_first_last': 'Cody Thomas',
#     'college': 'Oklahoma',
#     'height_inches': '4',
#     'starter_sw': 'N',
#     'jersey_number': '95',
#     'end_date': '',
#     'name_first': 'Cody',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'D10',
#     'primary_position': '9',
#     'birth_date': '1994-10-08T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Thomas, Cody',
#     'name_use': 'Cody',
#     'player_id': '642137',
#     'name_last': 'Thomas',
#     'team_id': '119',
#     'start_date': '2020-01-24T00:00:00',
#     'name_full': 'Thomas, Cody'},
#    {'position_txt': 'P',
#     'weight': '225',
#     'name_display_first_last': 'Blake Treinen',
#     'college': 'South Dakota State',
#     'height_inches': '5',
#     'starter_sw': 'N',
#     'jersey_number': '49',
#     'end_date': '',
#     'name_first': 'Blake',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2014-04-12T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1988-06-30T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Treinen, Blake',
#     'name_use': 'Blake',
#     'player_id': '595014',
#     'name_last': 'Treinen',
#     'team_id': '119',
#     'start_date': '2019-12-15T00:00:00',
#     'name_full': 'Treinen, Blake'},
#    {'position_txt': '3B',
#     'weight': '202',
#     'name_display_first_last': 'Justin Turner',
#     'college': 'Cal State Fullerton',
#     'height_inches': '11',
#     'starter_sw': 'N',
#     'jersey_number': '10',
#     'end_date': '',
#     'name_first': 'Justin',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '5',
#     'pro_debut_date': '2009-09-08T00:00:00',
#     'status_code': 'A',
#     'primary_position': '5',
#     'birth_date': '1984-11-23T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Turner, Justin',
#     'name_use': 'Justin',
#     'player_id': '457759',
#     'name_last': 'Turner',
#     'team_id': '119',
#     'start_date': '2016-12-23T00:00:00',
#     'name_full': 'Turner, Justin'},
#    {'position_txt': 'P',
#     'weight': '155',
#     'name_display_first_last': 'Edwin Uceta',
#     'college': '',
#     'height_inches': '0',
#     'starter_sw': 'N',
#     'jersey_number': '92',
#     'end_date': '',
#     'name_first': 'Edwin',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'D10',
#     'primary_position': '1',
#     'birth_date': '1998-01-09T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Uceta, Edwin',
#     'name_use': 'Edwin',
#     'player_id': '670955',
#     'name_last': 'Uceta',
#     'team_id': '119',
#     'start_date': '2020-01-24T00:00:00',
#     'name_full': 'Uceta, Edwin'},
#    {'position_txt': 'P',
#     'weight': '225',
#     'name_display_first_last': 'Julio Urias',
#     'college': '',
#     'height_inches': '0',
#     'starter_sw': 'N',
#     'jersey_number': '7',
#     'end_date': '',
#     'name_first': 'Julio',
#     'bats': 'L',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2016-05-27T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1996-08-12T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'L',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Urias, Julio',
#     'name_use': 'Julio',
#     'player_id': '628711',
#     'name_last': 'Urias',
#     'team_id': '119',
#     'start_date': '2016-05-27T00:00:00',
#     'name_full': 'Urias, Julio'},
#    {'position_txt': 'P',
#     'weight': '210',
#     'name_display_first_last': 'Mitchell White',
#     'college': 'Santa Clara',
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '66',
#     'end_date': '',
#     'name_first': 'Mitchell',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '1',
#     'birth_date': '1994-12-28T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'R',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'White, Mitchell',
#     'name_use': 'Mitchell',
#     'player_id': '669952',
#     'name_last': 'White',
#     'team_id': '119',
#     'start_date': '2019-11-20T00:00:00',
#     'name_full': 'White, Mitchell'},
#    {'position_txt': 'P',
#     'weight': '215',
#     'name_display_first_last': 'Alex Wood',
#     'college': 'Georgia',
#     'height_inches': '4',
#     'starter_sw': 'N',
#     'jersey_number': '57',
#     'end_date': '',
#     'name_first': 'Robert',
#     'bats': 'R',
#     'team_code': 'lan',
#     'height_feet': '6',
#     'pro_debut_date': '2013-05-30T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1991-01-12T00:00:00',
#     'team_abbrev': 'LAD',
#     'throws': 'L',
#     'team_name': 'Los Angeles Dodgers',
#     'name_display_last_first': 'Wood, Alex',
#     'name_use': 'Alex',
#     'player_id': '622072',
#     'name_last': 'Wood',
#     'team_id': '119',
#     'start_date': '2020-01-15T00:00:00',
#     'name_full': 'Wood, Alex'}]}}

# %%
import pandas as pd

df = pd.DataFrame.from_dict(response_LAD.json()['roster_40'])
print(len(df))
print(df.columns)
df.head()
# Out:
# 3
# Index(['copyRight', 'queryResults'], dtype='object')
#                                                    copyRight  \
# created     Copyright 2020 MLB Advanced Media, L.P.  Use ...
# row         Copyright 2020 MLB Advanced Media, L.P.  Use ...
# totalSize   Copyright 2020 MLB Advanced Media, L.P.  Use ...
#
#                                                 queryResults
# created                                  2020-07-09T18:01:12
# row        [{'position_txt': 'P', 'weight': '195', 'name_...
# totalSize                                                 42

# %%
time.sleep(5)

url = "https://mlb-data.p.rapidapi.com/json/named.roster_40.bam"

querystring = {"team_id":"'147'"}

headers = {
    'x-rapidapi-host': "mlb-data.p.rapidapi.com",
    'x-rapidapi-key': "96bb6e2228msh55393630fa64dbbp12e689jsn961aa3a10166"
    }

response_NYY = requests.request("GET", url, headers=headers, params=querystring)

print(response_NYY.text)
# Out:
# {"roster_40":{"copyRight":" Copyright 2020 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt  ","queryResults":{"created":"2020-07-09T19:00:12","totalSize":"39","row":[{"position_txt":"P","weight":"190","name_display_first_last":"Albert Abreu","college":"","height_inches":"2","starter_sw":"N","jersey_number":"84","end_date":"","name_first":"Albert","bats":"R","team_code":"nya","height_feet":"6","pro_debut_date":"","status_code":"RM","primary_position":"1","birth_date":"1995-09-26T00:00:00","team_abbrev":"NYY","throws":"R","team_name":"New York Yankees","name_display_last_first":"Abreu, Albert","name_use":"Albert","player_id":"656061","name_last":"Abreu","team_id":"147","start_date":"2017-11-20T00:00:00","name_full":"Abreu, Albert"},{"position_txt":"3B","weight":"211","name_display_first_last":"Miguel Andujar","college":"","height_inches":"0","starter_sw":"N","jersey_number":"41","end_date":"","name_first":"Miguel","bats":"R","team_code":"nya","height_feet":"6","pro_debut_date":"2017-06-28T00:00:00","status_code":"A","primary_position":"5","birth_date":"1995-03-02T00:00:00","team_abbrev":"NYY","throws":"R","team_name":"New York Yankees","name_display_last_first":"Andujar, Miguel","name_use":"Miguel","player_id":"609280","name_last":"Andujar","team_id":"147","start_date":"2016-11-18T00:00:00","name_full":"Andujar, Miguel"},{"position_txt":"P","weight":"200","name_display_first_last":"Zack Britton","college":"","height_inches":"1","starter_sw":"N","jersey_number":"53","end_date":"","name_first":"Zackary","bats":"L","team_code":"nya","height_feet":"6","pro_debut_date":"2011-04-03T00:00:00","status_code":"A","primary_position":"1","birth_date":"1987-12-22T00:00:00","team_abbrev":"NYY","throws":"L","team_name":"New York Yankees","name_display_last_first":"Britton, Zack","name_use":"Zack","player_id":"502154","name_last":"Britton","team_id":"147","start_date":"2019-01-11T00:00:00","name_full":"Britton, Zack"},{"position_txt":"P","weight":"208","name_display_first_last":"Luis Cessa","college":"","height_inches":"0","starter_sw":"N","jersey_number":"85","end_date":"","name_first":"Luis","bats":"R","team_code":"nya","height_feet":"6","pro_debut_date":"2016-04-08T00:00:00","status_code":"D10","primary_position":"1","birth_date":"1992-04-25T00:00:00","team_abbrev":"NYY","throws":"R","team_name":"New York Yankees","name_display_last_first":"Cessa, Luis","name_use":"Luis","player_id":"570666","name_last":"Cessa","team_id":"147","start_date":"2015-12-09T00:00:00","name_full":"Cessa, Luis"},{"position_txt":"P","weight":"218","name_display_first_last":"Aroldis Chapman","college":"","height_inches":"4","starter_sw":"N","jersey_number":"54","end_date":"","name_first":"Albertin","bats":"L","team_code":"nya","height_feet":"6","pro_debut_date":"2010-08-31T00:00:00","status_code":"A","primary_position":"1","birth_date":"1988-02-28T00:00:00","team_abbrev":"NYY","throws":"L","team_name":"New York Yankees","name_display_last_first":"Chapman, Aroldis","name_use":"Aroldis","player_id":"547973","name_last":"Chapman","team_id":"147","start_date":"2016-12-15T00:00:00","name_full":"Chapman, Aroldis"},{"position_txt":"P","weight":"220","name_display_first_last":"Gerrit Cole","college":"UCLA","height_inches":"4","starter_sw":"N","jersey_number":"45","end_date":"","name_first":"Gerrit","bats":"R","team_code":"nya","height_feet":"6","pro_debut_date":"2013-06-11T00:00:00","status_code":"A","primary_position":"1","birth_date":"1990-09-08T00:00:00","team_abbrev":"NYY","throws":"R","team_name":"New York Yankees","name_display_last_first":"Cole, Gerrit","name_use":"Gerrit","player_id":"543037","name_last":"Cole","team_id":"147","start_date":"2019-12-18T00:00:00","name_full":"Cole, Gerrit"},{"position_txt":"2B","weight":"185","name_display_first_last":"Thairo Estrada","college":"","height_inches":"10","starter_sw":"N","jersey_number":"71","end_date":"","name_first":"Tha ...

# %%
response_NYY.json().keys()
# Out:
# dict_keys(['roster_40'])

# %%
for key in response_NYY.json().keys():
    print(key)
    value = response_NYY.json()[key] #Use standard dictionary formatting
    print(type(value)) #What type is it?
    print('\n\n') #Separate out data
# Out:
# roster_40
# <class 'dict'>

# %%
response_NYY.json()['roster_40']
# Out:
# {'copyRight': ' Copyright 2020 MLB Advanced Media, L.P.  Use of any content on this page acknowledges agreement to the terms posted here http://gdx.mlb.com/components/copyright.txt  ',
#  'queryResults': {'created': '2020-07-09T19:00:12',
#   'totalSize': '39',
#   'row': [{'position_txt': 'P',
#     'weight': '190',
#     'name_display_first_last': 'Albert Abreu',
#     'college': '',
#     'height_inches': '2',
#     'starter_sw': 'N',
#     'jersey_number': '84',
#     'end_date': '',
#     'name_first': 'Albert',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '1',
#     'birth_date': '1995-09-26T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Abreu, Albert',
#     'name_use': 'Albert',
#     'player_id': '656061',
#     'name_last': 'Abreu',
#     'team_id': '147',
#     'start_date': '2017-11-20T00:00:00',
#     'name_full': 'Abreu, Albert'},
#    {'position_txt': '3B',
#     'weight': '211',
#     'name_display_first_last': 'Miguel Andujar',
#     'college': '',
#     'height_inches': '0',
#     'starter_sw': 'N',
#     'jersey_number': '41',
#     'end_date': '',
#     'name_first': 'Miguel',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2017-06-28T00:00:00',
#     'status_code': 'A',
#     'primary_position': '5',
#     'birth_date': '1995-03-02T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Andujar, Miguel',
#     'name_use': 'Miguel',
#     'player_id': '609280',
#     'name_last': 'Andujar',
#     'team_id': '147',
#     'start_date': '2016-11-18T00:00:00',
#     'name_full': 'Andujar, Miguel'},
#    {'position_txt': 'P',
#     'weight': '200',
#     'name_display_first_last': 'Zack Britton',
#     'college': '',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '53',
#     'end_date': '',
#     'name_first': 'Zackary',
#     'bats': 'L',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2011-04-03T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1987-12-22T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'L',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Britton, Zack',
#     'name_use': 'Zack',
#     'player_id': '502154',
#     'name_last': 'Britton',
#     'team_id': '147',
#     'start_date': '2019-01-11T00:00:00',
#     'name_full': 'Britton, Zack'},
#    {'position_txt': 'P',
#     'weight': '208',
#     'name_display_first_last': 'Luis Cessa',
#     'college': '',
#     'height_inches': '0',
#     'starter_sw': 'N',
#     'jersey_number': '85',
#     'end_date': '',
#     'name_first': 'Luis',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2016-04-08T00:00:00',
#     'status_code': 'D10',
#     'primary_position': '1',
#     'birth_date': '1992-04-25T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Cessa, Luis',
#     'name_use': 'Luis',
#     'player_id': '570666',
#     'name_last': 'Cessa',
#     'team_id': '147',
#     'start_date': '2015-12-09T00:00:00',
#     'name_full': 'Cessa, Luis'},
#    {'position_txt': 'P',
#     'weight': '218',
#     'name_display_first_last': 'Aroldis Chapman',
#     'college': '',
#     'height_inches': '4',
#     'starter_sw': 'N',
#     'jersey_number': '54',
#     'end_date': '',
#     'name_first': 'Albertin',
#     'bats': 'L',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2010-08-31T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1988-02-28T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'L',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Chapman, Aroldis',
#     'name_use': 'Aroldis',
#     'player_id': '547973',
#     'name_last': 'Chapman',
#     'team_id': '147',
#     'start_date': '2016-12-15T00:00:00',
#     'name_full': 'Chapman, Aroldis'},
#    {'position_txt': 'P',
#     'weight': '220',
#     'name_display_first_last': 'Gerrit Cole',
#     'college': 'UCLA',
#     'height_inches': '4',
#     'starter_sw': 'N',
#     'jersey_number': '45',
#     'end_date': '',
#     'name_first': 'Gerrit',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2013-06-11T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1990-09-08T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Cole, Gerrit',
#     'name_use': 'Gerrit',
#     'player_id': '543037',
#     'name_last': 'Cole',
#     'team_id': '147',
#     'start_date': '2019-12-18T00:00:00',
#     'name_full': 'Cole, Gerrit'},
#    {'position_txt': '2B',
#     'weight': '185',
#     'name_display_first_last': 'Thairo Estrada',
#     'college': '',
#     'height_inches': '10',
#     'starter_sw': 'N',
#     'jersey_number': '71',
#     'end_date': '',
#     'name_first': 'Thairo',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '5',
#     'pro_debut_date': '2019-04-21T00:00:00',
#     'status_code': 'RM',
#     'primary_position': '4',
#     'birth_date': '1996-02-22T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Estrada, Thairo',
#     'name_use': 'Thairo',
#     'player_id': '642731',
#     'name_last': 'Estrada',
#     'team_id': '147',
#     'start_date': '2017-11-20T00:00:00',
#     'name_full': 'Estrada, Thairo'},
#    {'position_txt': 'CF',
#     'weight': '195',
#     'name_display_first_last': 'Estevan Florial',
#     'college': '',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '90',
#     'end_date': '',
#     'name_first': 'Estevan',
#     'bats': 'L',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '8',
#     'birth_date': '1997-11-25T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Florial, Estevan',
#     'name_use': 'Estevan',
#     'player_id': '664314',
#     'name_last': 'Florial',
#     'team_id': '147',
#     'start_date': '2019-11-20T00:00:00',
#     'name_full': 'Florial, Estevan'},
#    {'position_txt': '1B',
#     'weight': '225',
#     'name_display_first_last': 'Mike Ford',
#     'college': 'Princeton',
#     'height_inches': '0',
#     'starter_sw': 'N',
#     'jersey_number': '72',
#     'end_date': '',
#     'name_first': 'Michael',
#     'bats': 'L',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2019-04-18T00:00:00',
#     'status_code': 'A',
#     'primary_position': '3',
#     'birth_date': '1992-07-04T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Ford, Mike',
#     'name_use': 'Mike',
#     'player_id': '645801',
#     'name_last': 'Ford',
#     'team_id': '147',
#     'start_date': '2019-04-16T00:00:00',
#     'name_full': 'Ford, Mike'},
#    {'position_txt': 'RF',
#     'weight': '212',
#     'name_display_first_last': 'Clint Frazier',
#     'college': '',
#     'height_inches': '11',
#     'starter_sw': 'N',
#     'jersey_number': '77',
#     'end_date': '',
#     'name_first': 'Clint',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '5',
#     'pro_debut_date': '2017-07-01T00:00:00',
#     'status_code': 'A',
#     'primary_position': '9',
#     'birth_date': '1994-09-06T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Frazier, Clint',
#     'name_use': 'Clint',
#     'player_id': '640449',
#     'name_last': 'Frazier',
#     'team_id': '147',
#     'start_date': '2017-07-01T00:00:00',
#     'name_full': 'Frazier, Clint'},
#    {'position_txt': 'P',
#     'weight': '163',
#     'name_display_first_last': 'Deivi Garcia',
#     'college': '',
#     'height_inches': '9',
#     'starter_sw': 'N',
#     'jersey_number': '83',
#     'end_date': '',
#     'name_first': 'Deivi',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '5',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '1',
#     'birth_date': '1999-05-19T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Garcia, Deivi',
#     'name_use': 'Deivi',
#     'player_id': '665620',
#     'name_last': 'Garcia',
#     'team_id': '147',
#     'start_date': '2019-11-20T00:00:00',
#     'name_full': 'Garcia, Deivi'},
#    {'position_txt': 'CF',
#     'weight': '195',
#     'name_display_first_last': 'Brett Gardner',
#     'college': 'College of Charleston',
#     'height_inches': '11',
#     'starter_sw': 'N',
#     'jersey_number': '11',
#     'end_date': '',
#     'name_first': 'Brett',
#     'bats': 'L',
#     'team_code': 'nya',
#     'height_feet': '5',
#     'pro_debut_date': '2008-06-30T00:00:00',
#     'status_code': 'A',
#     'primary_position': '8',
#     'birth_date': '1983-08-24T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'L',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Gardner, Brett',
#     'name_use': 'Brett',
#     'player_id': '458731',
#     'name_last': 'Gardner',
#     'team_id': '147',
#     'start_date': '2020-01-11T00:00:00',
#     'name_full': 'Gardner, Brett'},
#    {'position_txt': 'P',
#     'weight': '185',
#     'name_display_first_last': 'Luis Gil',
#     'college': '',
#     'height_inches': '2',
#     'starter_sw': 'N',
#     'jersey_number': '81',
#     'end_date': '',
#     'name_first': 'Luis',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '1',
#     'birth_date': '1998-06-03T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Gil, Luis',
#     'name_use': 'Luis',
#     'player_id': '661563',
#     'name_last': 'Gil',
#     'team_id': '147',
#     'start_date': '2019-11-20T00:00:00',
#     'name_full': 'Gil, Luis'},
#    {'position_txt': 'P',
#     'weight': '215',
#     'name_display_first_last': 'Chad Green',
#     'college': 'Louisville',
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '57',
#     'end_date': '',
#     'name_first': 'Chad',
#     'bats': 'L',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2016-05-16T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1991-05-24T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Green, Chad',
#     'name_use': 'Chad',
#     'player_id': '643338',
#     'name_last': 'Green',
#     'team_id': '147',
#     'start_date': '2016-05-14T00:00:00',
#     'name_full': 'Green, Chad'},
#    {'position_txt': 'P',
#     'weight': '205',
#     'name_display_first_last': 'J.A. Happ',
#     'college': 'Northwestern',
#     'height_inches': '5',
#     'starter_sw': 'N',
#     'jersey_number': '33',
#     'end_date': '',
#     'name_first': 'James',
#     'bats': 'L',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2007-06-30T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1982-10-19T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'L',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Happ, J.A.',
#     'name_use': 'J.A.',
#     'player_id': '457918',
#     'name_last': 'Happ',
#     'team_id': '147',
#     'start_date': '2018-12-17T00:00:00',
#     'name_full': 'Happ, J.A.'},
#    {'position_txt': 'P',
#     'weight': '210',
#     'name_display_first_last': 'Ben Heller',
#     'college': 'Olivet Nazarene',
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '61',
#     'end_date': '',
#     'name_first': 'Benjamin',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2016-08-26T00:00:00',
#     'status_code': 'RM',
#     'primary_position': '1',
#     'birth_date': '1991-08-05T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Heller, Ben',
#     'name_use': 'Ben',
#     'player_id': '621294',
#     'name_last': 'Heller',
#     'team_id': '147',
#     'start_date': '2016-08-11T00:00:00',
#     'name_full': 'Heller, Ben'},
#    {'position_txt': 'CF',
#     'weight': '205',
#     'name_display_first_last': 'Aaron Hicks',
#     'college': '',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '31',
#     'end_date': '',
#     'name_first': 'Aaron',
#     'bats': 'S',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2013-04-01T00:00:00',
#     'status_code': 'A',
#     'primary_position': '8',
#     'birth_date': '1989-10-02T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Hicks, Aaron',
#     'name_use': 'Aaron',
#     'player_id': '543305',
#     'name_last': 'Hicks',
#     'team_id': '147',
#     'start_date': '2015-11-11T00:00:00',
#     'name_full': 'Hicks, Aaron'},
#    {'position_txt': 'C',
#     'weight': '202',
#     'name_display_first_last': 'Kyle Higashioka',
#     'college': '',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '66',
#     'end_date': '',
#     'name_first': 'Kyle',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2017-04-10T00:00:00',
#     'status_code': 'A',
#     'primary_position': '2',
#     'birth_date': '1990-04-20T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Higashioka, Kyle',
#     'name_use': 'Kyle',
#     'player_id': '543309',
#     'name_last': 'Higashioka',
#     'team_id': '147',
#     'start_date': '2016-11-04T00:00:00',
#     'name_full': 'Higashioka, Kyle'},
#    {'position_txt': 'P',
#     'weight': '232',
#     'name_display_first_last': 'Jonathan Holder',
#     'college': 'Mississippi State',
#     'height_inches': '2',
#     'starter_sw': 'N',
#     'jersey_number': '56',
#     'end_date': '',
#     'name_first': 'Jonathan',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2016-09-02T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1993-06-09T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Holder, Jonathan',
#     'name_use': 'Jonathan',
#     'player_id': '656547',
#     'name_last': 'Holder',
#     'team_id': '147',
#     'start_date': '2016-09-02T00:00:00',
#     'name_full': 'Holder, Jonathan'},
#    {'position_txt': 'RF',
#     'weight': '282',
#     'name_display_first_last': 'Aaron Judge',
#     'college': 'Fresno State',
#     'height_inches': '7',
#     'starter_sw': 'N',
#     'jersey_number': '99',
#     'end_date': '',
#     'name_first': 'Aaron',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2016-08-13T00:00:00',
#     'status_code': 'A',
#     'primary_position': '9',
#     'birth_date': '1992-04-26T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Judge, Aaron',
#     'name_use': 'Aaron',
#     'player_id': '592450',
#     'name_last': 'Judge',
#     'team_id': '147',
#     'start_date': '2016-08-13T00:00:00',
#     'name_full': 'Judge, Aaron'},
#    {'position_txt': 'P',
#     'weight': '230',
#     'name_display_first_last': 'Tommy Kahnle',
#     'college': 'Lynn, FL',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '48',
#     'end_date': '',
#     'name_first': 'Thomas',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2014-04-03T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1989-08-07T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Kahnle, Tommy',
#     'name_use': 'Tommy',
#     'player_id': '592454',
#     'name_last': 'Kahnle',
#     'team_id': '147',
#     'start_date': '2017-07-19T00:00:00',
#     'name_full': 'Kahnle, Tommy'},
#    {'position_txt': 'P',
#     'weight': '210',
#     'name_display_first_last': 'Michael King',
#     'college': 'Boston College',
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '73',
#     'end_date': '',
#     'name_first': 'Michael',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2019-09-27T00:00:00',
#     'status_code': 'RM',
#     'primary_position': '1',
#     'birth_date': '1995-05-25T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'King, Michael',
#     'name_use': 'Michael',
#     'player_id': '650633',
#     'name_last': 'King',
#     'team_id': '147',
#     'start_date': '2019-09-19T00:00:00',
#     'name_full': 'King, Michael'},
#    {'position_txt': 'P',
#     'weight': '190',
#     'name_display_first_last': 'Brooks Kriske',
#     'college': 'Southern California',
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '82',
#     'end_date': '',
#     'name_first': 'Brooks',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '1',
#     'birth_date': '1994-02-03T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Kriske, Brooks',
#     'name_use': 'Brooks',
#     'player_id': '621139',
#     'name_last': 'Kriske',
#     'team_id': '147',
#     'start_date': '2019-11-20T00:00:00',
#     'name_full': 'Kriske, Brooks'},
#    {'position_txt': '2B',
#     'weight': '220',
#     'name_display_first_last': 'DJ LeMahieu',
#     'college': 'Louisiana State',
#     'height_inches': '4',
#     'starter_sw': 'N',
#     'jersey_number': '26',
#     'end_date': '',
#     'name_first': 'David',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2011-05-30T00:00:00',
#     'status_code': 'D10',
#     'primary_position': '4',
#     'birth_date': '1988-07-13T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'LeMahieu, DJ',
#     'name_use': 'DJ',
#     'player_id': '518934',
#     'name_last': 'LeMahieu',
#     'team_id': '147',
#     'start_date': '2019-01-14T00:00:00',
#     'name_full': 'LeMahieu, DJ'},
#    {'position_txt': 'P',
#     'weight': '165',
#     'name_display_first_last': 'Jonathan Loaisiga',
#     'college': '',
#     'height_inches': '11',
#     'starter_sw': 'N',
#     'jersey_number': '43',
#     'end_date': '',
#     'name_first': 'Jonathan',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '5',
#     'pro_debut_date': '2018-06-15T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1994-11-02T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Loaisiga, Jonathan',
#     'name_use': 'Jonathan',
#     'player_id': '642528',
#     'name_last': 'Loaisiga',
#     'team_id': '147',
#     'start_date': '2017-11-20T00:00:00',
#     'name_full': 'Loaisiga, Jonathan'},
#    {'position_txt': 'P',
#     'weight': '175',
#     'name_display_first_last': 'Luis Medina',
#     'college': '',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '80',
#     'end_date': '',
#     'name_first': 'Luis',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '1',
#     'birth_date': '1999-05-03T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Medina, Luis',
#     'name_use': 'Luis',
#     'player_id': '665622',
#     'name_last': 'Medina',
#     'team_id': '147',
#     'start_date': '2019-11-20T00:00:00',
#     'name_full': 'Medina, Luis'},
#    {'position_txt': 'P',
#     'weight': '228',
#     'name_display_first_last': 'Jordan Montgomery',
#     'college': 'South Carolina',
#     'height_inches': '6',
#     'starter_sw': 'N',
#     'jersey_number': '47',
#     'end_date': '',
#     'name_first': 'Jordan',
#     'bats': 'L',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2017-04-12T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1992-12-27T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'L',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Montgomery, Jordan',
#     'name_use': 'Jordan',
#     'player_id': '656756',
#     'name_last': 'Montgomery',
#     'team_id': '147',
#     'start_date': '2017-04-12T00:00:00',
#     'name_full': 'Montgomery, Jordan'},
#    {'position_txt': 'P',
#     'weight': '205',
#     'name_display_first_last': 'Nick Nelson',
#     'college': 'Gulf Coast CC, FL',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '79',
#     'end_date': '',
#     'name_first': 'Nicholas',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '1',
#     'birth_date': '1995-12-05T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Nelson, Nick',
#     'name_use': 'Nick',
#     'player_id': '656793',
#     'name_last': 'Nelson',
#     'team_id': '147',
#     'start_date': '2019-11-20T00:00:00',
#     'name_full': 'Nelson, Nick'},
#    {'position_txt': 'P',
#     'weight': '246',
#     'name_display_first_last': 'Adam Ottavino',
#     'college': 'Northeastern',
#     'height_inches': '5',
#     'starter_sw': 'N',
#     'jersey_number': '0',
#     'end_date': '',
#     'name_first': 'Adam',
#     'bats': 'S',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2010-05-29T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1985-11-22T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Ottavino, Adam',
#     'name_use': 'Adam',
#     'player_id': '493603',
#     'name_last': 'Ottavino',
#     'team_id': '147',
#     'start_date': '2019-01-24T00:00:00',
#     'name_full': 'Ottavino, Adam'},
#    {'position_txt': 'P',
#     'weight': '227',
#     'name_display_first_last': 'James Paxton',
#     'college': 'Kentucky',
#     'height_inches': '4',
#     'starter_sw': 'N',
#     'jersey_number': '65',
#     'end_date': '',
#     'name_first': 'James',
#     'bats': 'L',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2013-09-07T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1988-11-06T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'L',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Paxton, James',
#     'name_use': 'James',
#     'player_id': '572020',
#     'name_last': 'Paxton',
#     'team_id': '147',
#     'start_date': '2018-11-19T00:00:00',
#     'name_full': 'Paxton, James'},
#    {'position_txt': 'C',
#     'weight': '230',
#     'name_display_first_last': 'Gary Sanchez',
#     'college': '',
#     'height_inches': '2',
#     'starter_sw': 'N',
#     'jersey_number': '24',
#     'end_date': '',
#     'name_first': 'Gary',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2015-10-03T00:00:00',
#     'status_code': 'A',
#     'primary_position': '2',
#     'birth_date': '1992-12-02T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Sanchez, Gary',
#     'name_use': 'Gary',
#     'player_id': '596142',
#     'name_last': 'Sanchez',
#     'team_id': '147',
#     'start_date': '2017-09-04T00:00:00',
#     'name_full': 'Sanchez, Gary'},
#    {'position_txt': 'LF',
#     'weight': '245',
#     'name_display_first_last': 'Giancarlo Stanton',
#     'college': '',
#     'height_inches': '6',
#     'starter_sw': 'N',
#     'jersey_number': '27',
#     'end_date': '',
#     'name_first': 'Giancarlo',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2010-06-08T00:00:00',
#     'status_code': 'A',
#     'primary_position': '7',
#     'birth_date': '1989-11-08T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Stanton, Giancarlo',
#     'name_use': 'Giancarlo',
#     'player_id': '519317',
#     'name_last': 'Stanton',
#     'team_id': '147',
#     'start_date': '2017-12-11T00:00:00',
#     'name_full': 'Stanton, Giancarlo'},
#    {'position_txt': 'P',
#     'weight': '218',
#     'name_display_first_last': 'Masahiro Tanaka',
#     'college': '',
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '19',
#     'end_date': '',
#     'name_first': 'Masahiro',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2014-04-04T00:00:00',
#     'status_code': 'A',
#     'primary_position': '1',
#     'birth_date': '1988-11-01T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Tanaka, Masahiro',
#     'name_use': 'Masahiro',
#     'player_id': '547888',
#     'name_last': 'Tanaka',
#     'team_id': '147',
#     'start_date': '2014-01-22T00:00:00',
#     'name_full': 'Tanaka, Masahiro'},
#    {'position_txt': 'CF',
#     'weight': '220',
#     'name_display_first_last': 'Mike Tauchman',
#     'college': 'Bradley',
#     'height_inches': '2',
#     'starter_sw': 'N',
#     'jersey_number': '39',
#     'end_date': '',
#     'name_first': 'Michael',
#     'bats': 'L',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2017-06-27T00:00:00',
#     'status_code': 'A',
#     'primary_position': '8',
#     'birth_date': '1990-12-03T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'L',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Tauchman, Mike',
#     'name_use': 'Mike',
#     'player_id': '643565',
#     'name_last': 'Tauchman',
#     'team_id': '147',
#     'start_date': '2019-03-23T00:00:00',
#     'name_full': 'Tauchman, Mike'},
#    {'position_txt': 'SS',
#     'weight': '205',
#     'name_display_first_last': 'Gleyber Torres',
#     'college': '',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '25',
#     'end_date': '',
#     'name_first': 'Gleyber',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2018-04-22T00:00:00',
#     'status_code': 'A',
#     'primary_position': '6',
#     'birth_date': '1996-12-13T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Torres, Gleyber',
#     'name_use': 'Gleyber',
#     'player_id': '650402',
#     'name_last': 'Torres',
#     'team_id': '147',
#     'start_date': '2017-11-20T00:00:00',
#     'name_full': 'Torres, Gleyber'},
#    {'position_txt': '3B',
#     'weight': '215',
#     'name_display_first_last': 'Gio Urshela',
#     'college': '',
#     'height_inches': '0',
#     'starter_sw': 'N',
#     'jersey_number': '29',
#     'end_date': '',
#     'name_first': 'Giovanny',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2015-06-09T00:00:00',
#     'status_code': 'A',
#     'primary_position': '5',
#     'birth_date': '1991-10-11T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Urshela, Gio',
#     'name_use': 'Gio',
#     'player_id': '570482',
#     'name_last': 'Urshela',
#     'team_id': '147',
#     'start_date': '2019-04-06T00:00:00',
#     'name_full': 'Urshela, Gio'},
#    {'position_txt': '1B',
#     'weight': '255',
#     'name_display_first_last': 'Luke Voit',
#     'college': 'Missouri State',
#     'height_inches': '3',
#     'starter_sw': 'N',
#     'jersey_number': '59',
#     'end_date': '',
#     'name_first': 'Louis',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2017-06-25T00:00:00',
#     'status_code': 'A',
#     'primary_position': '3',
#     'birth_date': '1991-02-13T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Voit, Luke',
#     'name_use': 'Luke',
#     'player_id': '572228',
#     'name_last': 'Voit',
#     'team_id': '147',
#     'start_date': '2018-07-29T00:00:00',
#     'name_full': 'Voit, Luke'},
#    {'position_txt': 'SS',
#     'weight': '188',
#     'name_display_first_last': 'Tyler Wade',
#     'college': '',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '14',
#     'end_date': '',
#     'name_first': 'Tyler',
#     'bats': 'L',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '2017-06-27T00:00:00',
#     'status_code': 'A',
#     'primary_position': '6',
#     'birth_date': '1994-11-23T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Wade, Tyler',
#     'name_use': 'Tyler',
#     'player_id': '642180',
#     'name_last': 'Wade',
#     'team_id': '147',
#     'start_date': '2017-06-27T00:00:00',
#     'name_full': 'Wade, Tyler'},
#    {'position_txt': 'P',
#     'weight': '175',
#     'name_display_first_last': 'Miguel Yajure',
#     'college': '',
#     'height_inches': '1',
#     'starter_sw': 'N',
#     'jersey_number': '89',
#     'end_date': '',
#     'name_first': 'Miguel',
#     'bats': 'R',
#     'team_code': 'nya',
#     'height_feet': '6',
#     'pro_debut_date': '',
#     'status_code': 'RM',
#     'primary_position': '1',
#     'birth_date': '1998-05-01T00:00:00',
#     'team_abbrev': 'NYY',
#     'throws': 'R',
#     'team_name': 'New York Yankees',
#     'name_display_last_first': 'Yajure, Miguel',
#     'name_use': 'Miguel',
#     'player_id': '664337',
#     'name_last': 'Yajure',
#     'team_id': '147',
#     'start_date': '2019-11-20T00:00:00',
#     'name_full': 'Yajure, Miguel'}]}}

# %%
df = pd.DataFrame.from_dict(response_NYY.json()['roster_40'])
print(len(df))
print(df.columns)
df.head()
# Out:
# 3
# Index(['copyRight', 'queryResults'], dtype='object')
#                                                    copyRight  \
# created     Copyright 2020 MLB Advanced Media, L.P.  Use ...
# row         Copyright 2020 MLB Advanced Media, L.P.  Use ...
# totalSize   Copyright 2020 MLB Advanced Media, L.P.  Use ...
#
#                                                 queryResults
# created                                  2020-07-09T19:00:12
# row        [{'position_txt': 'P', 'weight': '190', 'name_...
# totalSize                                                 39
